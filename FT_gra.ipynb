# %% [markdown]
# - frc/pos/vel file:
#     - no. atoms
#     - timestep no, time, energy
#     - atom id, x, y, z component of frc/pos/vel
#     - repeat
# - init.pdb

# %% [markdown]
# ### Create xyz file with energies, positions and forces

# %%
from ase import io
import numpy as np
from ase.visualize import view

# %%
input = io.read("gra-wat-protonic-defects/input.xyz", index=":")

# %%
input[0].get_forces()
# Out:
# array([[-2.09133547e+00,  1.23988888e+00, -1.40006862e+00],
#        [ 2.34278940e-01, -7.50813600e-01,  7.22994300e-02],
#        [-1.68150159e+00,  1.39996578e+00,  3.71267320e-01],
#        [ 1.48656054e+00, -8.90578780e-01,  1.45262197e+00],
#        [-9.37887080e-01,  3.33610945e+00,  1.27778695e+00],
#        [ 2.24616731e+00,  1.14187842e+00,  6.82165140e-01],
#        [-3.39807304e+00,  1.72078805e+00, -1.06392257e+00],
#        [ 4.75345590e-01, -1.98638303e+00,  4.72928750e-01],
#        [-9.75476600e-02,  3.44784960e-01,  1.78280310e-01],
#        [ 1.27994667e+00, -7.24691190e-01,  9.08010860e-01],
#        [ 1.38356214e+00, -1.21196670e+00, -4.28397240e-01],
#        [ 4.43566750e-01, -1.05687774e+00, -1.06957900e-02],
#        [ 9.70334400e-02,  2.96499640e-01,  7.49733740e-01],
#        [-1.71991388e+00,  1.44989660e+00, -1.19546022e+00],
#        [ 5.60639371e+00, -1.04217103e+00,  3.53475290e-01],
#        [-1.38716168e+00, -3.08763802e+00, -1.07868070e+00],
#        [-1.17550850e-01,  7.60429530e-01,  3.28587000e-02],
#        [ 1.12290368e+00, -9.83292770e-01,  1.98232070e-01],
#        [-8.27072530e-01, -1.05302109e+00, -6.22258430e-01],
#        [ 2.19613364e+00, -2.15849269e+00,  7.23354220e-01],
#        [-1.50018739e+00, -4.25054810e-01,  4.40841380e-01],
#        [ 1.18718126e+00, -1.46023244e+00, -5.19414300e-01],
#        [ 1.06772780e+00,  6.65195860e-01, -6.55528510e-01],
#        [-1.56621332e+00,  3.68428826e+00, -3.06578360e-01],
#        [-1.70669840e-01,  1.94272570e-01, -4.53696900e-01],
#        [-3.98356469e+00, -1.92303104e+00,  1.58297691e+00],
#        [ 1.06387115e+00, -1.10639720e+00, -2.44727902e+00],
#        [-1.23392392e+00,  1.28524314e+00,  1.41616373e+00],
#        [ 9.71054310e-01,  2.81211858e+00, -4.91183580e-01],
#        [ 1.95954071e+00,  5.08507679e+00,  7.28650700e-02],
#        [-5.07006155e+00, -1.05620926e+00, -3.29049810e-01],
#        [ 1.08089185e+00, -2.57115478e+00,  3.40002710e-01],
#        [ 6.07757410e-01, -7.69119860e-01, -4.57810660e-01],
#        [-8.41933500e-01, -2.31640986e+00, -4.81721920e-01],
#        [-3.78867506e+00, -6.82525100e-01,  9.81133040e-01],
#        [-1.27886681e+00,  1.32087864e+00,  8.78134640e-01],
#        [-4.58283746e+00,  8.77466150e-01, -8.15502560e-01],
0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 12.350006533176298 0.0 0.0 12.350006533176298 0.0 20.000009251743517 0.0 0.0 20.000009251743517 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="0.0 0.0 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.23399892 3.5699988 -0.25499991">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.22699791 2.12700134 -0.28399883">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.04100065 1.41999942 -0.33800136">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.01899746 4.22899905 -0.36299969">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.18300211 7.79600271 -0.0910026">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.24099994 6.36900228 -0.06399869">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.0510021 5.71900333 -0.20199752">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 8.55600173 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.20500001 12.13500712 -0.0619984">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.20800044 10.71200198 0.07500029">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="-0.02099775 10.01300651 0.10799978">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.44599995 0.01700246 -0.08400159">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.70800292 3.5389996 0.21199897">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.58400083 2.16200112 0.07199985">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.42700248 1.4750021 -0.02999906">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.47000342 4.27800086 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.68599974 7.87200314 0.0090013">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.71300365 6.46100503 0.10699963">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.4540011 5.73099977 -0.02099775">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="2.45600139 8.51900166 -0.05999811">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="3.66400184 12.13500712 0.02599848">

# %%
view(input[7], viewer="x3d")
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 141.13058308">
#     <group/>
#   </viewpoint>
#   <transform translation="-6.175000091524886 -6.416999444630862 -10.500001152924872">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 12.350000183049772 0.0 0.0 12.350000183049772 12.833998889261723 0.0 0.0 12.833998889261723 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 21.000002305849744">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 12.350000183049772 0.0 0.0 12.350000183049772 12.833998889261723 0.0 0.0 12.833998889261723 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 12.350000183049772 0.0 0.0 12.350000183049772 0.0 21.000002305849744 0.0 0.0 21.000002305849744 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 12.833998889261723 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 12.350000183049772 0.0 0.0 12.350000183049772 0.0 21.000002305849744 0.0 0.0 21.000002305849744 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="0.61800013 0.35599973 12.46293136">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.85828833 3.86773136 12.17678884">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.80748837 2.42401845 12.08886128">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.5699736 1.74663617 12.31551212">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.61800013 0.35599973 18.76032591">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.90162847 3.91834822 18.6008864">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.88338032 2.49275011 18.51496284">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.64187661 1.79559564 18.62885712">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.58697395 4.58794525 12.23667106">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.85477671 8.15438639 12.27154331">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.86698853 6.72371611 12.23559683">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.60277571 5.99042467 12.34944666">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.69125784 4.60186684 18.66505972">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.896986 8.18683765 18.82644237">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.90865647 6.76283607 18.80165941">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.69770745 6.05884358 18.79270891">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.57842932 8.9083639 12.32823777">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.84172984 12.47746257 12.33442703">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1.80085408 11.06164577 12.32652112">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.56590846 10.34594311 12.41874824">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="0.68098439 8.89352154 18.80178059">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.565 0.565 0.565"/>
#             </appearance>
#             <sphere radius="0.76"/>
#           </shape>
#         </transform>
#         <transform translation="1

# %% [markdown]
# ### Randomly sample 500 structures - g-h2o
# - the dataset contains tens of thousands of structures so its better to sample these before merging the files than merging and then sampling to save computational effort

# %%
print("No. configurations = ", len(input))
# Out:
# No. configurations =  5845

# %%
import random

sampled_atom_idx = random.sample(range(len(input)), 200)

# %%
# save sampled atom indices
np.save('sampled_atom_idx.npy', sampled_atom_idx)

# %%
sampled_atom_idx = np.load('sampled_atom_idx.npy')

# %%
atoms_list = [input[i] for i in sampled_atom_idx]

# %%
io.write("sampled_dataset_200.xyz", atoms_list)

# %%
sampled_dataset_200 = io.read("sampled_dataset_200.xyz", index=':')

# %% [markdown]
# ### Validation set
# - randomly select 100 structures from the sampled data set
# - then create training sets from the remaining structures

# %%
sampled_atom_idx
# Out:
# array([4966, 5286, 3686, 2642,  454, 3240, 4483,  389,  953,  219, 5760,
#        1431, 3138, 3891, 3613, 3727, 4632,  646, 5548, 2840,  414, 3900,
#        4219,  116, 2791, 3677, 1283, 5632, 4617,  608,  500,  489, 3109,
#         400, 1440,   87, 1696, 4662, 1213, 2853,  569, 3128, 1142, 4605,
#        1318, 5713, 5799, 2426, 5699, 1608, 1137, 4354, 5127, 1081, 1791,
#        2201, 2157, 2303, 5707,  443, 1167, 1441, 5724, 2505,  404, 4596,
#        1091,  266, 2019, 5751, 3623, 4209, 5522,  426,  392, 5272, 3217,
#        1413, 3378, 4569, 2678, 1458, 3975, 2086,  845, 5141, 3314, 2103,
#        5682, 4004, 2940,  399, 1820, 1602, 5324, 2787, 1119, 3976, 1592,
#        1967,  711, 2799, 5658, 3281,  293, 4706, 3052,  587, 4075, 3505,
#        3500, 4297, 4092, 3705, 1496, 2706, 2421, 5055, 5258, 4904, 3198,
#        4233, 3444, 1063, 1155, 1429, 3863, 2770,  621, 1988, 3003, 5087,
#         900, 1124, 3034, 5796, 5147, 1019, 2718, 1484, 3649,  479, 5838,
#        2795,  841,  497, 4531, 3872,  492,  537, 5819, 4742, 3464, 3140,
#        4873, 2362,  864, 3511, 1665, 4844, 2874, 5003, 2702, 4965, 1099,
#        3129, 4457, 4444, 2749,  107, 2040, 5185, 3555, 2128,  801,  651,
#        4594, 2456, 1774, 3096, 4235, 3010, 4067, 1645,  177, 4063, 5644,
#        5221, 3778, 1410,  448, 4261,  681, 3822, 5323,  838, 1914, 2420,
#        4299,  119])

# %%
val_random_idx = random.sample(list(sampled_atom_idx), 100)

validation_set_100 = []
for i in val_random_idx:
    validation_set_100.append(input[i])

# %%
io.write("validation_set_100.xyz", validation_set_100)

# %%
validation_set_100 = io.read("validation_set_100.xyz", index=':')

# %% [markdown]
# Training sets

# %%
# 10
training_set_10 = []
for i in list(sampled_atom_idx):
    if i not in val_random_idx:
        training_set_10.append(input[i])
    if len(training_set_10) == 10:
        break

# 20
training_set_20 = []
for i in list(sampled_atom_idx):
    if i not in val_random_idx:
        training_set_20.append(input[i])
    if len(training_set_20) == 20:
        break
        
# 30
training_set_30 = []
for i in list(sampled_atom_idx):
    if i not in val_random_idx:
        training_set_30.append(input[i])
    if len(training_set_30) == 30:
        break
        
# 50
training_set_50 = []
for i in list(sampled_atom_idx):
    if i not in val_random_idx:
        training_set_50.append(input[i])
    if len(training_set_50) == 50:
        break

# 100
training_set_100 = []
for i in list(sampled_atom_idx):
    if i not in val_random_idx:
        training_set_100.append(input[i])
    if len(training_set_100) == 100:
        break

# %%
io.write("train_10.xyz", training_set_10)
io.write("train_20.xyz", training_set_20)
io.write("train_30.xyz", training_set_30)
io.write("train_50.xyz", training_set_50)
io.write("train_100.xyz", training_set_100)
